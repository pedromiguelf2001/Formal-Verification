# %% [markdown]
# # Control Flow Automaton (CFA)

# %% [markdown]
# ## Multiplicação de dois inteiros

# %% [markdown]
# <div>
# <img src="attachment:automato.png" width="500"/>
# </div>

# %% [markdown]
# ## Problema representado num autómato

# %% [markdown]
# ![331349975_1393097071431349_1603397457403138661_n.png](attachment:331349975_1393097071431349_1603397457403138661_n.png)

# %% [markdown]
# ## Grafo representado com recurso ao NetworkX

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()

# %%
edges = [[0, 1], [1, 2], [2, 3],[3,4],[3,5],[5,6],[6,7],[7,8],[8,3],[5,9],[9,10],[10,11],[11,3]]


G.add_edges_from(edges)
pos = nx.spring_layout(G)
plt.figure()
nx.draw(
    G, pos, edge_color='black', width=1, linewidths=2,
    node_size=300, node_color='pink', alpha=0.6,
    labels={node: node for node in G.nodes()}
)
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels={(0, 1): 'x = a', 
                 (1, 2): 'y = b',
                 (2, 3): 'z = 0',
                 (3, 4): 'y == 0',
                 (3, 5): 'y != 0',
                 (5, 6): '(y % 2) != 0',
                 (6, 7): 'y -= 1',
                 (7, 8): 'z += x',
                 (5, 9): '(y % 2) == 0',
                 (9, 10): 'x *= 2',
                 (10, 11): 'y /= 2',
                },
    font_color='red'
)
plt.axis('off')
plt.show()
